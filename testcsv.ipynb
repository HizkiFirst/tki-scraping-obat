# %%
import pandas as pd

# %%
data = pd.read_csv('acne-skincare.csv')
data
# Out:
#                                          product_name              category  \
# 0                       Noroid Soothing Lotion 200 ml  Perawatan Kecantikan
# 1   La Roche Posay Cicaplast Baume B5 Soothing Rep...  Perawatan Kecantikan
# 2   La Roche Posay Cicaplast Baume B5 Soothing Rep...  Perawatan Kecantikan
# 3   La Roche Posay Effaclar Purifying Foaming Gel ...  Perawatan Kecantikan
# 4            La Roche Posay Lipikar Baume AP+M 200 ml  Perawatan Kecantikan
# 5                Cetaphil Gentle Skin Cleanser 250 ml  Perawatan Kecantikan
# 6                  La Roche Posay Effaclar Duo+ 40 ml  Perawatan Kecantikan
# 7             La Roche Posay Lipikar Baume AP+M 75 ml  Perawatan Kecantikan
# 8                         Noroid Soothing Cream 80 ml  Perawatan Kecantikan
# 9                Derma Angel Acne Patch Day 12 Lembar  Perawatan Kecantikan
# 10  Labore Sensitive Skin Care Biomerepair Barrier...     Kebutuhan Lebaran
# ...
